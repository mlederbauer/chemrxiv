# %% [markdown]
# # Usage example: Basic usage
#
# ## Configure logging (for debugging)

# %%
import logging
import sys

# Configure logging to show DEBUG level messages
logging.basicConfig(
    level=logging.DEBUG,
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s",
    handlers=[logging.StreamHandler(sys.stdout)],
)

# Set logger for chemrxiv to DEBUG
chemrxiv_logger = logging.getLogger("chemrxiv")
chemrxiv_logger.setLevel(logging.DEBUG)

# %% [markdown]
# ## Initialize the ChemRxiv client

# %%
import chemrxiv

# Create a client with a smaller delay to speed up testing
client = chemrxiv.Client(delay_seconds=0)

# %% [markdown]
# ## Search for keywords and sort

# %%
# Test a simple search
logging.info("\nTesting search for 'catalysis'")
search = chemrxiv.Search(
    term="ammonia+decomposition", limit=None, sort=chemrxiv.SortCriterion.PUBLISHED_DATE_DESC
)

logging.info(f"Searching for {search.term} with limit {search.limit} and sort {search.sort}")
results = list(client.results(search))
logging.info(len(results))
logging.info(results)
# Out:
# 2025-06-03 16:12:50,653 - root - INFO -
# Testing search for 'catalysis'
# 2025-06-03 16:12:50,654 - root - INFO - Searching for ammonia+decomposition with limit None and sort SortCriterion.PUBLISHED_DATE_DESC
# 2025-06-03 16:12:50,655 - chemrxiv.client - INFO - Making search request: https://chemrxiv.org/engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&limit=10&sort=PUBLISHED_DATE_DESC
# 2025-06-03 16:12:50,655 - chemrxiv.client - INFO - Requesting URL (retry 0): https://chemrxiv.org/engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&limit=10&sort=PUBLISHED_DATE_DESC
# 2025-06-03 16:12:50,866 - urllib3.connectionpool - DEBUG - https://chemrxiv.org:443 "GET /engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&limit=10&sort=PUBLISHED_DATE_DESC HTTP/1.1" 200 None
# 2025-06-03 16:12:50,927 - chemrxiv.client - INFO - API returned total count: 8922
# 2025-06-03 16:12:50,927 - chemrxiv.client - INFO - Found 10 items in response
# 2025-06-03 16:12:50,928 - chemrxiv.client - INFO - Processed item: 6839f0291a8f9bdab5db710b - Late-Stage Modification of NHC Gold(I) Complexes: Fast Track to Ligand Design as a Key for New Reactivities in Gold-Catalysis
# 2025-06-03 16:12:50,928 - chemrxiv.client - INFO - Processed item: 68361b7c3ba0887c3353493f - Analytical method development of Bifenthrin in dried meat-based foods using gas chromatography coupled to mass spectrometry
# 2025-06-03 16:12:50,928 - chemrxiv.client - INFO - Processed item: 68316943c1cb1ecda019dad6 - Dehalogenative borylation of benzylic halides assisted by sodium dispersion
# 2025-06-03 16:12:50,928 - chemrxiv.client - INFO - Processed item: 6839c5141a8f9bdab5ce8235 - Continuous Hollow Skeletal Macroporous Aluminum Hydroxide Monoliths and Their Calcined Alumina Derivatives with High Diffuse Reflectance
# 2025-06-03 16:12:50,929 - chemrxiv.client - INFO - Processed item: 6838d652c1cb1ecda035c5b9 - Novel Bio-based Thermoplastic Polyurethanes Derived From Oleanolic Acid
# 2025-06-03 16:12:50,929 - chemrxiv.client - INFO - Processed item: 68398812c1cb1ecda04d4042 - H2-Eliminating Reductive N2 Binding: a Dinickel-Bridging Bent N2 Radical Anion and its Redox-Triggered N2 Release
# 2025-06-03 16:12:50,929 - chemrxiv.client - INFO - Processed item: 68398a9f1a8f9bdab5c877ed - Design Rules and Experimental Validation of Carbene–Metal–Amide Luminophores: Systematic Modification of the Amide Ligand
# 2025-06-03 16:12:50,929 - chemrxiv.client - INFO - Processed item: 6839b03d1a8f9bdab5cc7179 - Quantum Effects in Electric-Field–Driven Dissociation of Liquid Hydrogen Fluoride
# 2025-06-03 16:12:50,930 - chemrxiv.client - INFO - Processed item: 6838de133ba0887c33b5a9ac - Eliminating air pollution disparities requires more than emission reduction
# 2025-06-03 16:12:50,930 - chemrxiv.client - INFO - Processed item: 683870523ba0887c33a76e07 - A Crystalline Boravinylidene from an Arrested Hydroboration Reaction
# 2025-06-03 16:12:50,930 - chemrxiv.client - INFO - Making search request: https://chemrxiv.org/engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=10&limit=10&sort=PUBLISHED_DATE_DESC
# 2025-06-03 16:12:50,930 - chemrxiv.client - INFO - Requesting URL (retry 0): https://chemrxiv.org/engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=10&limit=10&sort=PUBLISHED_DATE_DESC
# 2025-06-03 16:12:51,112 - urllib3.connectionpool - DEBUG - https://chemrxiv.org:443 "GET /engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=10&limit=10&sort=PUBLISHED_DATE_DESC HTTP/1.1" 200 None
# 2025-06-03 16:12:51,114 - chemrxiv.client - INFO - API returned total count: 8922
# 2025-06-03 16:12:51,115 - chemrxiv.client - INFO - Found 10 items in response
# 2025-06-03 16:12:51,115 - chemrxiv.client - INFO - Processed item: 6838ce27c1cb1ecda034de24 - A Generalized Machine-Learning Framework for Developing Alchemical Many-Body Interaction Models for Polymer Grafted Nanoparticles
# 2025-06-03 16:12:51,116 - chemrxiv.client - INFO - Processed item: 683581aac1cb1ecda0ba848b - Circumventing problems introduced by matrix asymmetry in collocation calculations of vibrational spectra by exploiting near symmetry
# 2025-06-03 16:12:51,116 - chemrxiv.client - INFO - Processed item: 6838b2ba3ba0887c33afa90e - Peptide Charge Modulates Ion Binding to EF-Hand Motifs: A Molecular Dynamics Study
# 2025-06-03 16:12:51,116 - chemrxiv.client - INFO - Processed item: 6838a90e1a8f9bdab5aadbee - Optimized Biomimetic Syntheses of Discorhabdin B and Aleutianamine Drives a Deeper Exploration of their Anticancer Activities
# 2025-06-03 16:12:51,117 - chemrxiv.client - INFO - Processed item: 68386577c1cb1ecda026b70b - Leveraging Physics-Informed Neural Networks for Noise Reduction in Fluid Flow Data
# 2025-06-03 16:12:51,117 - chemrxiv.client - INFO - Processed item: 6838a1291a8f9bdab5a9f107 - Leveraging dynamic bonds to probe equilibrium topology in polymer networks
# 2025-06-03 16:12:51,117 - chemrxiv.client - INFO - Processed item: 683757e33ba0887c337d1dc3 - An Organometallic Chemistry Approach to Peptide Tricycles
# 2025-06-03 16:12:51,118 - chemrxiv.client - INFO - Processed item: 6835da7f3ba0887c3349477b - Increasing the chemical space of L-SIGN specific glycomimetics
# 2025-06-03 16:12:51,118 - chemrxiv.client - INFO - Processed item: 68380cdb3ba0887c33973698 - Evaluation of Bactericidal Efficacy, Load, and Safety of Ozonated Water under Overflow Conditions — Development of a Continuous Flow Immersion Method Using Low-Concentration Ozonated Water—
# 2025-06-03 16:12:51,118 - chemrxiv.client - INFO - Processed item: 6837e5aa3ba0887c3390e865 - Ni-Catalyzed Reductive Coupling of Acetals with Anhydrides and Vinyl Triflates via Single-Electron C–O Activation: A Polarity-Convergent Approach to Native and Umpolung Aldehyde Reactivity
# 2025-06-03 16:12:51,119 - chemrxiv.client - INFO - Making search request: https://chemrxiv.org/engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=20&limit=10&sort=PUBLISHED_DATE_DESC
# 2025-06-03 16:12:51,119 - chemrxiv.client - INFO - Requesting URL (retry 0): https://chemrxiv.org/engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=20&limit=10&sort=PUBLISHED_DATE_DESC
# 2025-06-03 16:12:51,490 - urllib3.connectionpool - DEBUG - https://chemrxiv.org:443 "GET /engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=20&limit=10&sort=PUBLISHED_DATE_DESC HTTP/1.1" 200 None
# 2025-06-03 16:12:51,492 - chemrxiv.client - INFO - API returned total count: 8922
# 2025-06-03 16:12:51,493 - chemrxiv.client - INFO - Found 10 items in response
# 2025-06-03 16:12:51,493 - chemrxiv.client - INFO - Processed item: 68378c55c1cb1ecda0087e12 - Simulation of Hydrogen Storage in MOF-5 and Li-MOF-5 by Ring Polymer Molecular Dynamics on Self-Consistently Fine-Tuned Machine-Learned    Potentials
# 2025-06-03 16:12:51,493 - chemrxiv.client - INFO - Processed item: 68378a17c1cb1ecda008258f - Hydrogen Diffusion in the Confinement between Graphene and Ni(111): Full-Dimensional Simulation of Nuclear Quantum Effects
# 2025-06-03 16:12:51,494 - chemrxiv.client - INFO - Processed item: 683709cac1cb1ecda0f482ce - From Membrane Composition to Antimicrobial Strategies: Experimental and Computational Approaches to AMP Design and Selectivity
# 2025-06-03 16:12:51,494 - chemrxiv.client - INFO - Processed item: 6836a45b3ba0887c3367ed97 - A Universal Method for Creating LCST-type Thermoresponsive Simple Polymer Coacervates
# 2025-06-03 16:12:51,495 - chemrxiv.client - INFO - Processed item: 682f187d1a8f9bdab5390703 - Leveraging Post-Pretrained LLMs for Inverse
# Engineering High-Capacity Hydrogen-Storage
# Metal-Organic Frameworks: From Virtual Structures
# to Synthesized Materials
# 2025-06-03 16:12:51,495 - chemrxiv.client - INFO - Processed item: 6836ae661a8f9bdab5652c9f - Understanding cation and surface charging effects at electrified interfaces using neural network interatomic potentials
# 2025-06-03 16:12:51,495 - chemrxiv.client - INFO - Processed item: 683711f33ba0887c3374b9b6 - Giving an Enzyme Scissors: Serotonin Derivatives as Potent Organocatalytic Switches of DNA Repair Enzyme OGG1
# 2025-06-03 16:12:51,496 - chemrxiv.client - INFO - Processed item: 68371b23c1cb1ecda0f6c222 - Prediction of excess enthalpy in binary mixtures through probabilistic matrix completion, with a GP enforced smoothness constraint
# 2025-06-03 16:12:51,496 - chemrxiv.client - INFO - Processed item: 6836f8091a8f9bdab56d7885 - Characterisation of small RNA-based therapeutics and their process impurities by fast, sensitive, and reproducible liquid chromatography high resolution mass spectrometry
# 2025-06-03 16:12:51,496 - chemrxiv.client - INFO - Processed item: 683027333ba0887c33668107 - Comment on “Air-stable double halide perovskite Cs2CuBiBr6: synthesis and memristor application” by A. Betal, A. Chetia, D. Saikia, K. Karmakar, G. Bera, N. V. Dambhare, A. K. Rath and S. Sahu, Phys. Chem. Chem. Phys., 2025, 27, 3150
# 2025-06-03 16:12:51,497 - chemrxiv.client - INFO - Making search request: https://chemrxiv.org/engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=30&limit=10&sort=PUBLISHED_DATE_DESC
# 2025-06-03 16:12:51,497 - chemrxiv.client - INFO - Requesting URL (retry 0): https://chemrxiv.org/engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=30&limit=10&sort=PUBLISHED_DATE_DESC
# 2025-06-03 16:12:52,102 - urllib3.connectionpool - DEBUG - https://chemrxiv.org:443 "GET /engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=30&limit=10&sort=PUBLISHED_DATE_DESC HTTP/1.1" 200 None
# 2025-06-03 16:12:52,104 - chemrxiv.client - INFO - API returned total count: 8922
# 2025-06-03 16:12:52,105 - chemrxiv.client - INFO - Found 10 items in response
# 2025-06-03 16:12:52,105 - chemrxiv.client - INFO - Processed item: 6836b3103ba0887c3369b35a - Metal-Ligand Covalency of C-H Activating Iridium Complexes from L-edge Valence-to-Core Resonant Inelastic X-ray Scattering
# 2025-06-03 16:12:52,106 - chemrxiv.client - INFO - Processed item: 683161a63ba0887c33997e52 - Photoswitchable Organic Magnetic Materials
# 2025-06-03 16:12:52,106 - chemrxiv.client - INFO - Processed item: 683663e73ba0887c335f6aff - Enhanced Adsorption and Enzymatic Hydrolysis of Polyethylene Terephthalate by Cutinase with an N-Terminal Hydrophobic Tether
# 2025-06-03 16:12:52,107 - chemrxiv.client - INFO - Processed item: 681fa583e561f77ed4060307 - Concentrating Ammonia from Wastewater with Electrodialysis
# 2025-06-03 16:12:52,107 - chemrxiv.client - INFO - Processed item: 6835c630c1cb1ecda0c6d9f0 - An Extremely Versatile Polyglutamate Alignment Medium to Measure Residual Dipolar Couplings in non-Polar and Polar Solvents
# 2025-06-03 16:12:52,107 - chemrxiv.client - INFO - Processed item: 6835b0f5c1cb1ecda0c2f6dc - Sustainable Conversion of Carbon, Nitrogen and Water into HCN and CO at Atmospheric Pressure and Near Ambient Temperature
# 2025-06-03 16:12:52,107 - chemrxiv.client - INFO - Processed item: 6830214a3ba0887c3365dbab - g-C₃N₄/CoN₄ Heterojunction as a Sensor for Detecting Volatile Organic Compounds in Exhaled Human Breath: A Density Functional Study
# 2025-06-03 16:12:52,108 - chemrxiv.client - INFO - Processed item: 683303d11a8f9bdab5c9f1e3 - Tuning BN-Benzvalene Formation from BN-Dewar Benzene: Insights
# into Photochemical Synthesis
# 2025-06-03 16:12:52,108 - chemrxiv.client - INFO - Processed item: 683596263ba0887c333d44a1 - What Dictates the Optimal Concentration of Li-Based Battery Electrolytes? A Combined Experimental and Simulation Study
# 2025-06-03 16:12:52,108 - chemrxiv.client - INFO - Processed item: 68357a333ba0887c33386ea1 - Judicious Incorporation of Chalcogens in Multiresonant Thermally Activated Delayed Fluorescent Emitters Leads to OLEDs with Efficiencies Exceeding 36% and Showing Very Mild Efficiency Roll-Off
# 2025-06-03 16:12:52,109 - chemrxiv.client - INFO - Making search request: https://chemrxiv.org/engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=40&limit=10&sort=PUBLISHED_DATE_DESC
# 2025-06-03 16:12:52,109 - chemrxiv.client - INFO - Requesting URL (retry 0): https://chemrxiv.org/engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=40&limit=10&sort=PUBLISHED_DATE_DESC
# 2025-06-03 16:12:52,333 - urllib3.connectionpool - DEBUG - https://chemrxiv.org:443 "GET /engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=40&limit=10&sort=PUBLISHED_DATE_DESC HTTP/1.1" 200 None
# 2025-06-03 16:12:52,337 - chemrxiv.client - INFO - API returned total count: 8922
# 2025-06-03 16:12:52,337 - chemrxiv.client - INFO - Found 10 items in response
# 2025-06-03 16:12:52,338 - chemrxiv.client - INFO - Processed item: 6824479be561f77ed4bba511 - Toward Efficient Carbon Utilization and Renewable Energy Storage Zeolite-Based Catalysts in CO₂ Methanation
# 2025-06-03 16:12:52,338 - chemrxiv.client - INFO - Processed item: 6835abf53ba0887c33410d6d - All-atom Picture of Cucurbituril Detoxification Coordination
# 2025-06-03 16:12:52,339 - chemrxiv.client - INFO - Processed item: 6835621cc1cb1ecda0b4f462 - Revisiting hexakis(azulen-2-yl)benzenes: A new synthetic approach using Suzuki cross-coupling
# 2025-06-03 16:12:52,339 - chemrxiv.client - INFO - Processed item: 68340c4dc1cb1ecda074524d - Origins of Fluoroquinolone Protomers: Tuning and Separation in MALDI and Plasma Post Ionization.
# 2025-06-03 16:12:52,340 - chemrxiv.client - INFO - Processed item: 68350b773ba0887c331edbb2 - Biradical-mediated synergistic electrocatalysis using metal-free redox molecular catalysts
# 2025-06-03 16:12:52,340 - chemrxiv.client - INFO - Processed item: 6835121e3ba0887c33207f06 - Silicon Negative Electrodes for Lithium-Ion Batteries: Challenges, Advances, and Future Prospects
# 2025-06-03 16:12:52,340 - chemrxiv.client - INFO - Processed item: 6834e9b1c1cb1ecda0977dc9 - Influence of temperature on selenium mobility under contrasting redox conditions: a sediment flow-through reactor experiment
# 2025-06-03 16:12:52,341 - chemrxiv.client - INFO - Processed item: 683467e21a8f9bdab5f8f0bb - ChemChallenge: A Video Game for Teaching and Studying Thermodynamics Featuring In-game Currency, Shopping, Customization of Laboratory and Photochemistry
# 2025-06-03 16:12:52,341 - chemrxiv.client - INFO - Processed item: 682dc61b3ba0887c330be773 - Ammonia Evolution in Glycine Pyrolysis via Ionic-Pair Reaction Mechanisms
# 2025-06-03 16:12:52,341 - chemrxiv.client - INFO - Processed item: 683421c71a8f9bdab5f206a1 - Active Learning of Atomic Size Gas/Solid Potential Energy Surfaces via Physics Aware Models
# 2025-06-03 16:12:52,342 - chemrxiv.client - INFO - Making search request: https://chemrxiv.org/engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=50&limit=10&sort=PUBLISHED_DATE_DESC
# 2025-06-03 16:12:52,342 - chemrxiv.client - INFO - Requesting URL (retry 0): https://chemrxiv.org/engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=50&limit=10&sort=PUBLISHED_DATE_DESC
# 2025-06-03 16:12:52,857 - urllib3.connectionpool - DEBUG - https://chemrxiv.org:443 "GET /engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=50&limit=10&sort=PUBLISHED_DATE_DESC HTTP/1.1" 200 None
# 2025-06-03 16:12:52,861 - chemrxiv.client - INFO - API returned total count: 8922
# 2025-06-03 16:12:52,861 - chemrxiv.client - INFO - Found 10 items in response
# 2025-06-03 16:12
# 2025-06-03 16:12:53,091 - chemrxiv.client - INFO - Processed item: 682f899a1a8f9bdab54e36b0 - Separation of Redox Events Unlocks Electrocatalytic C–N Bond Formation with Inert Fluoroarenes
# 2025-06-03 16:12:53,092 - chemrxiv.client - INFO - Processed item: 6830ac14c1cb1ecda000513e - Iron (IV) Formation and the pH Dependent Kinetics of the Fenton Reaction
# 2025-06-03 16:12:53,092 - chemrxiv.client - INFO - Processed item: 6830745b3ba0887c336f5bff - Identification and elimination of surface emission in lanthanide (co-)doped zirconia nanocrystals
# 2025-06-03 16:12:53,092 - chemrxiv.client - INFO - Processed item: 682f90ba1a8f9bdab550df2f - Financially Driven Hydrothermal-based Wastewater Solids Management for Targeted Resource Recovery and Decarbonization in the Contiguous U.S.
# 2025-06-03 16:12:53,093 - chemrxiv.client - INFO - Processed item: 682ec5413ba0887c3332b980 - Adjacent radiocarbon dating of Iron Age site foundation
# 2025-06-03 16:12:53,093 - chemrxiv.client - INFO - Making search request: https://chemrxiv.org/engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=70&limit=10&sort=PUBLISHED_DATE_DESC
# 2025-06-03 16:12:53,093 - chemrxiv.client - INFO - Requesting URL (retry 0): https://chemrxiv.org/engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=70&limit=10&sort=PUBLISHED_DATE_DESC
# 2025-06-03 16:12:53,442 - urllib3.connectionpool - DEBUG - https://chemrxiv.org:443 "GET /engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=70&limit=10&sort=PUBLISHED_DATE_DESC HTTP/1.1" 200 None
# 2025-06-03 16:12:53,460 - chemrxiv.client - INFO - API returned total count: 8922
# 2025-06-03 16:12:53,460 - chemrxiv.client - INFO - Found 10 items in response
# 2025-06-03 16:12:53,460 - chemrxiv.client - INFO - Processed item: 68303e1c1a8f9bdab563252f - Data-Driven Evaluation as a Preliminary Tool to Judiciously Choose Covalent Organic Frameworks to be used as Fillers in Mixed Matrix Membranes for Hydrogen Separation
# 2025-06-03 16:12:53,461 - chemrxiv.client - INFO - Processed item: 682da19e3ba0887c33079427 - Solid-State Luminescent Responsive Bilayer Architecture based on Lanthanide MOFs for Ratiometric NO2 and SO2 Monitoring
# 2025-06-03 16:12:53,461 - chemrxiv.client - INFO - Processed item: 683010161a8f9bdab55e3497 - Intermolecular Interactions of Nitrogen-Substituted Chalcogen Heterocycles: From Electron Density to Binding Energy Landscapes
# 2025-06-03 16:12:53,461 - chemrxiv.client - INFO - Processed item: 682fca72c1cb1ecda0dbea36 - The Role of the Unusual 2-Tyr-1-carboxylate Non-heme Iron Motif in the Mechanism of N,N-Dimethylformamidase
# 2025-06-03 16:12:53,461 - chemrxiv.client - INFO - Processed item: 682fc6673ba0887c335ad212 - Toward Data-Driven Predictive Modeling of Electrocatalyst Stability and Surface Reconstruction
# 2025-06-03 16:12:53,462 - chemrxiv.client - INFO - Processed item: 682f3d651a8f9bdab53fe839 - Facile access to molecular Zintl phases with tetra-anionic group 14 elements
# 2025-06-03 16:12:53,462 - chemrxiv.client - INFO - Processed item: 682fb5f71a8f9bdab553f472 - HSADab2025: AI-powered Modelling of Human Serum Albumin
# 2025-06-03 16:12:53,462 - chemrxiv.client - INFO - Processed item: 682fa3ad3ba0887c3357cdd4 - Computational Catalysis and Machine Learning Applications to Water Treatment Technologies
# 2025-06-03 16:12:53,463 - chemrxiv.client - INFO - Processed item: 682f9e89c1cb1ecda0d822c9 - CO2 Reduction Using Chalcogen-Modified Copper Materials and Nanoclusters: Progress and Challenges
# 2025-06-03 16:12:53,463 - chemrxiv.client - INFO - Processed item: 682f7b2e1a8f9bdab54a2587 - Which modern AI methods provide accurate predictions of toxicological endpoints? Analysis of Tox24 challenge results.
#
# 2025-06-03 16:12:53,463 - chemrxiv.client - INFO - Making search request: https://chemrxiv.org/engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip
# 2025-06-03 16:12:53,886 - chemrxiv.client - INFO - Processed item: 682dda8cc1cb1ecda08fda87 - Bridging Theory and Experiment: A Teaching Project on L-Proline-Catalyzed Asymmetric Mannich Reactions
# 2025-06-03 16:12:53,886 - chemrxiv.client - INFO - Processed item: 6829c0e1927d1c2e666fa7a7 - Tapping the implications from the functional responses of CAM-B3LYP, LC-(\omega\)-HPBE, (\omega\)-B97XD in the redistribution of the electronic cloud of the available normal modes belonging to anthracene , tetracene, phenanthrene, and pyrene
# 2025-06-03 16:12:53,886 - chemrxiv.client - INFO - Processed item: 682aec063ba0887c33ad0391 - Azaanthraquinone PCET Catalysis Enables Chemoselective Decarboxylative Functionalization of Diverse Carboxylic Acids
# 2025-06-03 16:12:53,887 - chemrxiv.client - INFO - Processed item: 68276772927d1c2e6622233b - CO Reduction to Ethylene and Cyclopropane via a Trappable Ruthenium Methylidene
# 2025-06-03 16:12:53,887 - chemrxiv.client - INFO - Processed item: 682d90111a8f9bdab5fe970f - JOSR-Net: A jointly optimized sampling and reconstruction deep learning network for accelerated NMR spectroscopy
# 2025-06-03 16:12:53,888 - chemrxiv.client - INFO - Processed item: 682d11b93ba0887c33f27747 - CARBOT: A Mathematically Verified Rule-Based Molecule Generator for π-Conjugated and Aromatic Hydrocarbons
# 2025-06-03 16:12:53,888 - chemrxiv.client - INFO - Making search request: https://chemrxiv.org/engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=100&limit=10&sort=PUBLISHED_DATE_DESC
# 2025-06-03 16:12:53,888 - chemrxiv.client - INFO - Requesting URL (retry 0): https://chemrxiv.org/engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=100&limit=10&sort=PUBLISHED_DATE_DESC
# 2025-06-03 16:12:54,077 - urllib3.connectionpool - DEBUG - https://chemrxiv.org:443 "GET /engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=100&limit=10&sort=PUBLISHED_DATE_DESC HTTP/1.1" 200 None
# 2025-06-03 16:12:54,092 - chemrxiv.client - INFO - API returned total count: 8922
# 2025-06-03 16:12:54,092 - chemrxiv.client - INFO - Found 10 items in response
# 2025-06-03 16:12:54,093 - chemrxiv.client - INFO - Processed item: 682cec723ba0887c33eed416 - Catalytic Ammonia Synthesis via Protonation-Induced Cleavage of a Dinitrogen-Bridged Dimolybdenum Complex with a 𝜋8 Mo2(μ-N2) Core
# 2025-06-03 16:12:54,093 - chemrxiv.client - INFO - Processed item: 682cdd311a8f9bdab5e34de0 - Bis(Cyclooctadiene)Nickel(0)-Catalyzed Exhaustive C(sp2) and C(sp3)-X Hydrodehalogenation of Pyridines and Arenes Employing Ammonia Borane and Potassium Tert-Butoxide
# 2025-06-03 16:12:54,093 - chemrxiv.client - INFO - Processed item: 682731e5e561f77ed42a74a7 - Noble Metal-based High Entropy Alloy Nanoparticles Prepared by Pulsed Electrodeposition: An Approach for Medium Throughput Studies
# 2025-06-03 16:12:54,094 - chemrxiv.client - INFO - Processed item: 682c7867c1cb1ecda05b6362 - Assessment of the time correlation function-based approach for absorption spectrum calculations using time-dependent density functional theory and molecular dynamics simulations
# 2025-06-03 16:12:54,094 - chemrxiv.client - INFO - Processed item: 682c2214c1cb1ecda0521df1 - Engineering an Artificial Myxopyronin Derivative with Enhanced Metabolic Stability via Mutasynthesis
# 2025-06-03 16:12:54,094 - chemrxiv.client - INFO - Processed item: 682b0209c1cb1ecda02f7b69 - Late-Stage Sequential Functionalization of Arenes and Drug Molecules: A Facile Access to Biaryls and Azahelicenes
# 2025-06-03 16:12:54,095 - chemrxiv.client - INFO - Processed item: 68270569927d1c2e66165ad8 - Harnessing Machine Learning to Enhance Transition State Search with Interatomic Potentials and Generative Models
# 2025-06-03 16:12:54,095 - chemrxiv.client - INFO - Processed item: 682b4209c1cb1ecda036833a - Catalytic Enantioselective α-Allenylation of Acetonitrile
# 2025-06-03 16:12:54,095 - chemrxiv.client - INFO - Processed item: 682af9171a8f9bdab5a88f0a - Synthesis and Radiation Damage of Vacancy-Ordered Double Perovskites, ((NH4)(1-x)FAx)2SnBr6
# 2025-06-03 16:12:54,095 - chemrxiv.client - INFO - Processed item: 6829896fe561f77ed47a9430 - Binding and activation of dihydrogen and other small molecules in a dirhodium paddle wheel unit based three-dimensional porous coordination polymer: FTIR and computational studies
# 2025-06-03 16:12:54,096 - chemrxiv.client - INFO - Making search request: https://chemrxiv.org/engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=110&limit=10&sort=PUBLISHED_DATE_DESC
# 2025-06-03 16:12:54,096 - chemrxiv.client - INFO - Requesting URL (retry 0): https://chemrxiv.org/engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=110&limit=10&sort=PUBLISHED_DATE_DESC
# 2025-06-03 16:12:54,305 - urllib3.connectionpool - DEBUG - https://chemrxiv.org:443 "GET /engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=110&limit=10&sort=PUBLISHED_DATE_DESC HTTP/1.1" 200 None
# 2025-06-03 16:12:54,309 - chemrxiv.client - INFO - API returned total count: 8922
# 2025-06-03 16:12:54,309 - chemrxiv.client - INFO - Found 10 items in response
# 2025-06-03 16:12:54,310 - chemrxiv.client - INFO - Processed item: 682c50923ba0887c33d690d0 - Development and characterization of the first selective class IIb histone deacetylase degraders
# 2025-06-03 16:12:54,310 - chemrxiv.client - INFO - Processed item: 682b0911c1cb1ecda0305f2e - Crystal optics select weak response of ultrafast crystallography of the Photoactive Yellow Protein
# 2025-06-03 16:12:54,310 - chemrxiv.client - INFO - Processed item: 682223f5927d1c2e6646a93c - Exogenic and endogenic tuning of intrusion pressure in zinc imidazolate frameworks
# 2025-06-03 16:12:54,311 - chemrxiv.client - INFO - Processed item: 682a8d63927d1c2e6686770d - Polymer-modified catalyst supports as tailored local solvation environments to control reaction selectivity in liquid-phase chemical processes
# 2025-06-03 16:12:54,311 - chemrxiv.client - INFO - Processed item: 682a4229e561f77ed48dab08 - Photocatalytic Polyene Cyclization to Cyclopentyl Thioethers with Consecutive Quaternary Centers in Fluorinated Alcohols
# 2025-06-03 16:12:54,311 - chemrxiv.client - INFO - Processed item: 681e272450018ac7c52e0b6e - Rapid aerosol-phase synthesis of covalent organic framework coatings
# 2025-06-03 16:12:54,312 - chemrxiv.client - INFO - Processed item: 682612e250018ac7c55edb85 - Electron Donor-Acceptor Complex-Driven Strategy Enables Initiation of Photoiniferter RAFT Polymerization from Amines, Carboxylic Acids and Alcohols
# 2025-06-03 16:12:54,312 - chemrxiv.client - INFO - Processed item: 68278c39e561f77ed434dfbe - Synthesis of Cyclopentadienyl Rhodium Catalysts by Co-Cyclization of Two Different Alkynes
# 2025-06-03 16:12:54,312 - chemrxiv.client - INFO - Processed item: 68279cb5e561f77ed4395e6c - Sub-Nanometer Confinement Suppresses Autoionization of Water
# 2025-06-03 16:12:54,312 - chemrxiv.client - INFO - Processed item: 68275f5c50018ac7c588ae9e - Unexpected Hydricity of a Bis-Carbene Iridium Complex Provides Insight into Electronic Structure Impacts on Hydride Donor Ability
# 2025-06-03 16:12:54,313 - chemrxiv.client - INFO - Making search request: https://chemrxiv.org/engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=120&limit=10&sort=PUBLISHED_DATE_DESC
# 2025-06-03 16:12:54,313 - chemrxiv.client - INFO - Requesting URL (retry 0): https://chemrxiv.org/engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=120&limit=10&sort=PUBLISHED_DATE_DESC
# 2025-06-03 16:12:54,547 - urllib3.connectionpool - DEBUG - https://chemrxiv.org:443 "GET /engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=120&limit=10&sort=PUBLISHED_DATE_DESC HTTP/1.1" 200 None
# 2025-06-03 16:12:54,549 - chemrxiv.client - INFO - API returned total count: 8922
# 2025-06-03 16:12:54,549 - chemrxiv.client - INFO - Found 10 items in response
# 2025-06-03 16:12
- chemrxiv.client - INFO - API returned total count: 8922
# 2025-06-03 16:12:55,394 - chemrxiv.client - INFO - Found 10 items in response
# 2025-06-03 16:12:55,395 - chemrxiv.client - INFO - Processed item: 682427a950018ac7c5109ae7 - Prototyping and Modeling a Photovoltaic/Thermal Electrochemical Stripping System for Distributed Urine Nitrogen Recovery
# 2025-06-03 16:12:55,396 - chemrxiv.client - INFO - Processed item: 6823b289927d1c2e669d3033 - From Plastic Waste to Pharmaceutical
# Precursors: PET Upcycling through
# Ruthenium Catalysed Semi-Hydrogenation
# 2025-06-03 16:12:55,396 - chemrxiv.client - INFO - Processed item: 6822f290927d1c2e66782682 - A Novel Spectral Barcoding and Classification Approach for Complex Biological Samples using Multi-excitation Raman Spectroscopy (MX-Raman)
# 2025-06-03 16:12:55,397 - chemrxiv.client - INFO - Processed item: 682252c5e561f77ed4627e1f - Controlled aggregation of pyrene-based supramolecular nanostructures for light-driven switchable H2 or H2O2 production
# 2025-06-03 16:12:55,398 - chemrxiv.client - INFO - Processed item: 6822c576e561f77ed47fc581 - Expanding Cluster, Enhancing Adsorption: Investigating the Role of Electrostatic Configurations on Water Vapor Adsorption
# 2025-06-03 16:12:55,398 - chemrxiv.client - INFO - Processed item: 6822ab1c50018ac7c5d5d17f - Prediction of Potential Drug-Resistant ALK Kinase Mutations against Fourth-Generation Inhibitors NVL-655 and TPX-0131
# 2025-06-03 16:12:55,399 - chemrxiv.client - INFO - Processed item: 6823849b50018ac7c5fc5a52 - Grain Boundary Tuning Determines Iodide and Lithium-Ion Migration in a Solid Adiponitrile-LiI Molecular Crystal Electrolyte
# 2025-06-03 16:12:55,399 - chemrxiv.client - INFO - Processed item: 682360b0e561f77ed49be056 - Sintering of W-substituted Na3SbS4 Electrolytes: Effect of Phase Composition, Voids, and Interface Contact
# 2025-06-03 16:12:55,399 - chemrxiv.client - INFO - Processed item: 682353a9927d1c2e6687fa08 - Selective Synthesis of Unsaturated Imines via [py2TiI2(NPh)]2-Catalyzed Alkyne Carboamination
# 2025-06-03 16:12:55,400 - chemrxiv.client - INFO - Processed item: 68229d49e561f77ed479f4fe - Understanding Equilibrium Size Distribution of Metal Single Atoms, Clusters, and Particles from Thermodynamics
# 2025-06-03 16:12:55,400 - chemrxiv.client - INFO - Making search request: https://chemrxiv.org/engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=160&limit=10&sort=PUBLISHED_DATE_DESC
# 2025-06-03 16:12:55,401 - chemrxiv.client - INFO - Requesting URL (retry 0): https://chemrxiv.org/engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=160&limit=10&sort=PUBLISHED_DATE_DESC
# 2025-06-03 16:12:55,607 - urllib3.connectionpool - DEBUG - https://chemrxiv.org:443 "GET /engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=160&limit=10&sort=PUBLISHED_DATE_DESC HTTP/1.1" 200 None
# 2025-06-03 16:12:55,609 - chemrxiv.client - INFO - API returned total count: 8922
# 2025-06-03 16:12:55,610 - chemrxiv.client - INFO - Found 10 items in response
# 2025-06-03 16:12:55,610 - chemrxiv.client - INFO - Processed item: 682288f750018ac7c5d12ce5 - Carbon Monoxide Chemistry of a-V70I Mo-Nitrogenase: Evidence from EPR- and IR-Monitored Photolysis - or, what a Difference a Methyl Makes
#
# 2025-06-03 16:12:55,610 - chemrxiv.client - INFO - Processed item: 6822a1c8927d1c2e666c40bb - The Untapped Potential of Heterotrophic Protists in Engineered Water Systems
# 2025-06-03 16:12:55,611 - chemrxiv.client - INFO - Processed item: 68225a79927d1c2e66586ceb - Structural complexity driven by liquid-liquid crystal phase separation of smectics
# 2025-06-03 16:12:55,611 - chemrxiv.client - INFO - Processed item: 68222e15927d1c2e6647cf64 - What can be learned from the electrostatic environments within nitrogenase enzymes?
# 2025-06-03 16:13:53,475 - chemrxiv.client - INFO - Processed item: 669264155101a2ffa846f985 - A novel multi-molecular catalysis for CO2 decomposition
# 2025-06-03 16:13:53,476 - chemrxiv.client - INFO - Processed item: 669412c901103d79c5031a1c - Unveiling the Role of Solvent in Solution Phase Chemical Reactions Using Deep Potentials-based Enhanced Sampling Simulations
# 2025-06-03 16:13:53,477 - chemrxiv.client - INFO - Processed item: 6693ed825101a2ffa860395e - Simulations enabled by machine learning potentials predict sulfide solid electrolyte with covalent network structure and glassy behavior
# 2025-06-03 16:13:53,477 - chemrxiv.client - INFO - Processed item: 6682f21ac9c6a5c07aee087f - Plasmon Modulation in Copper Phosphide Nanocrystals
# 2025-06-03 16:13:53,478 - chemrxiv.client - INFO - Processed item: 6692501201103d79c5e6420c - UMRSF-TDDFT: Unrestricted Mixed-Reference Spin-Flip-TDDFT
# 2025-06-03 16:13:53,479 - chemrxiv.client - INFO - Processed item: 669234aa5101a2ffa84362de - Unlocking peroxide activation initiated by a solid-water interface
# 2025-06-03 16:13:53,479 - chemrxiv.client - INFO - Processed item: 66914b28c9c6a5c07a186df6 - Photoredox/Pyridine N-oxide Catalyzed Carbohydroxylation and Aminohydroxylation of α-Olefins.
# 2025-06-03 16:13:53,480 - chemrxiv.client - INFO - Processed item: 6694d07b5101a2ffa86d1de5 - Quantum nature of reactivity modification in vibrational polariton chemistry
# 2025-06-03 16:13:53,481 - chemrxiv.client - INFO - Processed item: 6690cfd401103d79c5c94f88 - Anti-Schistosomal Activity and ADMET Properties of 1,2,5-Oxadiazinane-Containing Compound Synthesized by Visible-Light Photoredox Catalysis
# 2025-06-03 16:13:53,482 - chemrxiv.client - INFO - Making search request: https://chemrxiv.org/engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=2000&limit=10&sort=PUBLISHED_DATE_DESC
# 2025-06-03 16:13:53,482 - chemrxiv.client - INFO - Requesting URL (retry 0): https://chemrxiv.org/engage/chemrxiv/public-api/v1/items?term=ammonia%2Bdecomposition&skip=2000&limit=10&sort=PUBLISHED_DATE_DESC
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 8
#       3 search = chemrxiv.Search(
#       4     term="ammonia+decomposition", limit=None, sort=chemrxiv.SortCriterion.PUBLISHED_DATE_DESC
#       5 )
#       7 logging.info(f"Searching for {search.term} with limit {search.limit} and sort {search.sort}")
# ----> 8 results = list(client.results(search))
#       9 logging.info(len(results))
#      10 logging.info(results)
#
# File ~/chemrxiv/chemrxiv/client.py:131, in Client.results(self, search)
#     128 full_url = url + "?" + urlencode(params)
#     130 logger.info(f"Making search request: {full_url}")
# --> 131 response = self._request(full_url)
#     133 if response.status_code != 200:
#     134     raise HTTPError(full_url, 0, response.status_code)
#
# File ~/chemrxiv/chemrxiv/client.py:189, in Client._request(self, url, retry_count)
#     187 try:
#     188     logger.info(f"Requesting URL (retry {retry_count}): {url}")
# --> 189     response = self._session.get(url)
#     190     self._last_request_time = time.time()
#     192     if response.status_code == 429:
#     193         # Too many requests - implement backoff
#
# File ~/chemrxiv/.venv/lib/python3.12/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/chemrxiv/.venv/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/chemrxiv/.venv/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/chemrxiv/.venv/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/chemrxiv/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/chemrxiv/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/chemrxiv/.venv/lib/python3.12/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File ~/.local/share/uv/python/cpython-3.12.10-macos-aarch64-none/lib/python3.12/http/client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File ~/.local/share/uv/python/cpython-3.12.10-macos-aarch64-none/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~/.local/share/uv/python/cpython-3.12.10-macos-aarch64-none/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~/.local/share/uv/python/cpython-3.12.10-macos-aarch64-none/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File ~/.local/share/uv/python/cpython-3.12.10-macos-aarch64-none/lib/python3.12/ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.local/share/uv/python/cpython-3.12.10-macos-aarch64-none/lib/python3.12/ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Inspect the results

# %%
for key in results[0]._raw.keys():
    print(f"{key}: {results[0]._raw[key]}")

## Download the PDF
results[0].pdf_url
results[0].download_pdf()
# Out:
# id: 6839f0291a8f9bdab5db710b
# doi: 10.26434/chemrxiv-2025-scfw4
# vor: None
# title: Late-Stage Modification of NHC Gold(I) Complexes: Fast Track to Ligand Design as a Key for New Reactivities in Gold-Catalysis
# abstract: Herein we report the synthesis of bulky N-heterocyclic carbene gold(I) complexes via an “on-metal” eightfold Suzuki coupling of a suitable precursor complex. An initial screening revealed the optimal reaction conditions furnishing a series of extremely bulky gold(I) complexes in extraordinary yields. One of these complexes shows one of the highest buried volumes published so far. This synthetic potential of this complex to open up completely new reactivity patterns was demonstrated by inverting the reactivity of gold catalysts towards 1,5-diynes, enabling a diastereoselective synthesis of benzofulvenes.
# contentType: {'id': '5ce663395846762193c9c430', 'name': 'Working Paper'}
# categories: [{'id': '605c72ef153207001f6470d4', 'name': 'Catalysis', 'description': 'Research on Catalysis'}, {'id': '60adf37803f321001cb10546', 'name': 'Homogeneous Catalysis', 'description': 'Research on Homogeneous Catalysis'}]
# subject: {'id': '5e68cb1bd1f19d49ce3ac739', 'name': 'Chemistry', 'description': 'Discover early research outputs such as working papers, posters and presentations in Chemistry.'}
# event: None
# status: PUBLISHED
# statusDate: 2025-06-03T13:25:15.447Z
# funders: [{'funderId': '10.13039/501100009052', 'name': 'Hector Fellow Academy', 'grantNumber': '', 'url': None, 'title': None}, {'funderId': '10.13039/501100004543', 'name': 'China Scholarship Council', 'grantNumber': '', 'url': None, 'title': None}]
# authors: [{'orcid': '0000-0002-6115-4674', 'title': 'Dr', 'firstName': 'Martin Christian', 'lastName': 'Dietl', 'institutions': [{'name': 'Heidelberg University', 'country': 'United States', 'rorId': 'https://ror.org/04rcqnp59'}]}, {'orcid': None, 'title': 'Miss', 'firstName': 'Melina', 'lastName': 'Maag', 'institutions': [{'name': 'Heidelberg University', 'country': 'United States', 'rorId': 'https://ror.org/04rcqnp59'}]}, {'orcid': None, 'title': 'Mr', 'firstName': 'Matthias', 'lastName': 'Scherr', 'institutions': [{'name': 'Heidelberg University', 'country': 'United States', 'rorId': 'https://ror.org/04rcqnp59'}]}, {'orcid': None, 'title': 'Dr', 'firstName': 'Qiaoying', 'lastName': 'Sun', 'institutions': [{'name': 'Heidelberg University', 'country': 'United States', 'rorId': 'https://ror.org/04rcqnp59'}]}, {'orcid': '0009-0000-0212-8719', 'title': 'Mr', 'firstName': 'Jan-Niklas', 'lastName': 'Haug', 'institutions': [{'name': 'Heidelberg University', 'country': 'United States', 'rorId': 'https://ror.org/04rcqnp59'}]}, {'orcid': '0000-0002-9107-4843', 'title': 'Dr', 'firstName': 'Jürgen', 'lastName': 'Graf', 'institutions': [{'name': 'Heidelberg University', 'country': 'United States', 'rorId': 'https://ror.org/04rcqnp59'}]}, {'orcid': None, 'title': 'Dr', 'firstName': 'Frank', 'lastName': 'Rominger', 'institutions': [{'name': 'Heidelberg University', 'country': 'United States', 'rorId': 'https://ror.org/04rcqnp59'}]}, {'orcid': None, 'title': 'Dr', 'firstName': 'Matthias', 'lastName': 'Rudolph', 'institutions': [{'name': 'Heidelberg University', 'country': 'United States', 'rorId': 'https://ror.org/04rcqnp59'}]}, {'orcid': None, 'title': 'Prof', 'firstName': 'A. Stephen K.', 'lastName': 'Hashmi', 'institutions': [{'name': 'Heidelberg University', 'country': 'United States', 'rorId': 'https://ror.org/04rcqnp59'}, {'name': 'King Abdulaziz University', 'country': 'Saudi Arabia', 'rorId': 'https://ror.org/02ma4wv74'}]}]
# metrics: [{'description': 'Abstract Views', 'value': 0}, {'description': 'Citations', 'value': 0}, {'description': 'Content Downloads', 'value': 0}]
# version: 1
# versionRefs: [{'version': '1', 'itemId': '6839f0291a8f9bdab5db710b', 'legacyId': None}]
# submittedDate: 2025-05-30T18:16:43.218Z
# publishedDate: 2025-06-03T13:25:15.447Z
# approvedDate: 2025-06-03T13:24:57.099Z
# keywords: ['N-Heterocyclic Carbenes', 'Gold', 'Gold-Catalysis', 'Benzofulvenes', 'Catalysis']
# hasCompetingInterests: False
# competingInterestsDeclaration: None
# gainedEthicsApproval: YES
# suppItems: [{'id': '6839f4a33ba0887c33e017d7', 'title': 'Late-Stage Modification of NHC Gold(I) Complexes: Fast Track to Ligand Design as a Key for New Reactivities in Gold-Catalysis', 'description': 'This is the supporting information of the manuscript, including full characterization of all new compounds, and single crystal structure data', 'asset': {'id': '6839f4b225330af59dd0e1cb', 'mimeType': 'application/pdf', 'fileName': 'Dietl6_12_SI.pdf', 'fileSizeBytes': 6564549, 'smallThumbnail': {'url': 'https://chemrxiv.org/engage/api-gateway/chemrxiv/assets/orp/resource/item/6839f4a33ba0887c33e017d7/smallThumb/late-stage-modification-of-nhc-gold-i-complexes-fast-track-to-ligand-design-as-a-key-for-new-reactivities-in-gold-catalysis.jpg'}, 'mediumThumbnail': {'url': 'https://chemrxiv.org/engage/api-gateway/chemrxiv/assets/orp/resource/item/6839f4a33ba0887c33e017d7/mediumThumb/late-stage-modification-of-nhc-gold-i-complexes-fast-track-to-ligand-design-as-a-key-for-new-reactivities-in-gold-catalysis.jpg'}, 'largeThumbnail': {'url': 'https://chemrxiv.org/engage/api-gateway/chemrxiv/assets/orp/resource/item/6839f4a33ba0887c33e017d7/largeThumb/late-stage-modification-of-nhc-gold-i-complexes-fast-track-to-ligand-design-as-a-key-for-new-reactivities-in-gold-catalysis.jpg'}, 'original': {'url': 'https://chemrxiv.org/engage/api-gateway/chemrxiv/assets/orp/resource/item/6839f4a33ba0887c33e017d7/original/late-stage-modification-of-nhc-gold-i-complexes-fast-track-to-ligand-design-as-a-key-for-new-reactivities-in-gold-catalysis.pdf'}}}]
# asset: {'id': '6839f47525330af59dd0b120', 'mimeType': 'application/pdf', 'fileName': 'Dietl6_13.pdf', 'fileSizeBytes': 1355672, 'smallThumbnail': {'url': 'https://chemrxiv.org/engage/api-gateway/chemrxiv/assets/orp/resource/item/6839f0291a8f9bdab5db710b/smallThumb/late-stage-modification-of-nhc-gold-i-complexes-fast-track-to-ligand-design-as-a-key-for-new-reactivities-in-gold-catalysis.jpg'}, 'mediumThumbnail': {'url': 'https://chemrxiv.org/engage/api-gateway/chemrxiv/assets/orp/resource/item/6839f0291a8f9bdab5db710b/mediumThumb/late-stage-modification-of-nhc-gold-i-complexes-fast-track-to-ligand-design-as-a-key-for-new-reactivities-in-gold-catalysis.jpg'}, 'largeThumbnail': {'url': 'https://chemrxiv.org/engage/api-gateway/chemrxiv/assets/orp/resource/item/6839f0291a8f9bdab5db710b/largeThumb/late-stage-modification-of-nhc-gold-i-complexes-fast-track-to-ligand-design-as-a-key-for-new-reactivities-in-gold-catalysis.jpg'}, 'original': {'url': 'https://chemrxiv.org/engage/api-gateway/chemrxiv/assets/orp/resource/item/6839f0291a8f9bdab5db710b/original/late-stage-modification-of-nhc-gold-i-complexes-fast-track-to-ligand-design-as-a-key-for-new-reactivities-in-gold-catalysis.pdf'}}
# license: {'id': '5cc9d9bf7d4e0000ac04ef25', 'name': 'CC BY NC ND 4.0', 'description': 'This license will allow Site users to copy and redistribute the Content in any medium or format. However, the Content may not be used for commercial purposes and if the user remixes, transforms or builds upon the Content they may not redistribute the modified material. There is a requirement to attribute the Author upon reuse of the Content.', 'url': 'https://creativecommons.org/licenses/by-nc-nd/4.0/'}
# webLinks: []
# origin: CHEMRXIV
# termsAcceptance: True
# versionNote:
# latestComments: []
# commentsCount: 0
# isLatestVersion: True
# legacyId: None
# './6839f0291a8f9bdab5db710b.pdf'

# %% [markdown]
# ## Get all available categories

# %%
print("\nExample 2: Get all categories")
categories = client.categories()
print(f"Found {len(categories)} categories")
for i, category in enumerate(categories[:5], 1):  # Just print the first 5
    print(f"{i}. {category.name} ({category.id})")
    if category.description:
        print(f"   Description: {category.description}")
    if category.count:
        print(f"   Count: {category.count}")
    print()
# Out:
# Example 2: Get all categories
# 2025-06-03 15:50:06,905 - chemrxiv.client - INFO - Requesting URL (retry 0): https://chemrxiv.org/engage/chemrxiv/public-api/v1/categories
# 2025-06-03 15:50:06,990 - urllib3.connectionpool - DEBUG - https://chemrxiv.org:443 "GET /engage/chemrxiv/public-api/v1/categories HTTP/1.1" 200 None
# Found 214 categories
# 1. Acid Catalysis (60adf37803f321001cb10541)
#    Description: Research on Acid Catalysis
#    Count: 134
#
# 2. Aggregates and Assemblies (60adf37803f321001cb104bd)
#    Description: Research on Aggregates and Assemblies
#    Count: 232
#
# 3. Agriculture and Food Chemistry (605c72ef153207001f6470dd)
#    Description: Research on Agriculture and Food Chemistry
#    Count: 331
#
# 4. Alloys (60adf37803f321001cb104be)
#    Description: Research on Alloys
#    Count: 116
#
# 5. Analytical Apparatus (60adf37803f321001cb104fb)
#    Description: Research on Analytical Apparatus
#    Count: 172

# %% [markdown]
# ## Get all available licenses

# %%
print("\nExample 3: Get all licenses")
licenses = client.licenses()
print(f"Found {len(licenses)} licenses")
for i, license in enumerate(licenses, 1):
    print(f"{i}. {license.name} ({license.id})")
    if license.url:
        print(f"   URL: {license.url}")
    print()
# Out:
# Example 3: Get all licenses
# 2025-06-03 15:50:06,995 - chemrxiv.client - INFO - Requesting URL (retry 0): https://chemrxiv.org/engage/chemrxiv/public-api/v1/licenses
# 2025-06-03 15:50:07,064 - urllib3.connectionpool - DEBUG - https://chemrxiv.org:443 "GET /engage/chemrxiv/public-api/v1/licenses HTTP/1.1" 200 None
# Found 3 licenses
# 1. CC BY 4.0 (5cc9d9bf7d4e0000ac04ef23)
#    URL: https://creativecommons.org/licenses/by/4.0/
#
# 2. CC BY NC 4.0 (601bf4e28d966b96c9bbbdf3)
#    URL: https://creativecommons.org/licenses/by-nc/4.0/
#
# 3. CC BY NC ND 4.0 (5cc9d9bf7d4e0000ac04ef25)
#    URL: https://creativecommons.org/licenses/by-nc-nd/4.0/

# %% [markdown]
# ## Get paper by ChemRxiv ID

# %%
paper_id = (
    "6826a61850018ac7c5739260"  # Use one of the real paper IDs from the search
)    

paper = client.item(paper_id)
print(f"Title: {paper.title}")
print(f"Authors: {', '.join(str(author) for author in paper.authors)}")
print(
    f"Abstract: {paper.abstract[:100]}..."
)  # First 100 chars of abstract
print(f"DOI: {paper.doi}")
# Out:
# 2025-06-03 15:50:07,090 - chemrxiv.client - INFO - Requesting URL (retry 0): https://chemrxiv.org/engage/chemrxiv/public-api/v1/items/6826a61850018ac7c5739260
# 2025-06-03 15:50:07,285 - urllib3.connectionpool - DEBUG - https://chemrxiv.org:443 "GET /engage/chemrxiv/public-api/v1/items/6826a61850018ac7c5739260 HTTP/1.1" 200 None
# Title: Enantioselective and Diastereoselective Synthesis of Spiroazabicyclo[2.n]alkanes by Rhodium-Catalyzed Cyclopropanations
# Authors: Joshua Sailer, Duc Ly, Andrew  Wang, Djamaladdin Musaev, Huw Davies
# Abstract: Spirocyclopropanes have become a prevalent structural motif in drug discovery campaigns. However, me...
# DOI: 10.26434/chemrxiv-2025-5j4tn

# %% [markdown]
# ## Get a paper by DOI

# %%
doi = (
    "10.26434/chemrxiv-2025-5j4tn"  # Use the DOI from the first search result
)

paper = client.item_by_doi(doi)
print(f"Title: {paper.title}")
print(f"Authors: {', '.join(str(author) for author in paper.authors)}")
print(f"Abstract: {paper.abstract[:100]}...")
print(f"ID: {paper.id}")
# Out:
# 2025-06-03 15:50:07,290 - chemrxiv.client - INFO - Requesting URL (retry 0): https://chemrxiv.org/engage/chemrxiv/public-api/v1/items/doi/10.26434/chemrxiv-2025-5j4tn
# 2025-06-03 15:50:07,383 - urllib3.connectionpool - DEBUG - https://chemrxiv.org:443 "GET /engage/chemrxiv/public-api/v1/items/doi/10.26434/chemrxiv-2025-5j4tn HTTP/1.1" 200 None
# Title: Enantioselective and Diastereoselective Synthesis of Spiroazabicyclo[2.n]alkanes by Rhodium-Catalyzed Cyclopropanations
# Authors: Joshua Sailer, Duc Ly, Andrew  Wang, Djamaladdin Musaev, Huw Davies
# Abstract: Spirocyclopropanes have become a prevalent structural motif in drug discovery campaigns. However, me...
# ID: 6826a61850018ac7c5739260

# %% [markdown]
# ## Search with filters

# %%
filtered_search = chemrxiv.Search(
term="catalysis",
limit=3,
search_date_from="2023-01-01T00:00:00.000Z",
search_date_to="2025-05-19T00:00:00.000Z",  # Use current date
category_ids=["605c72ef153207001f6470d4"],  # "Catalysis" category ID
)
filtered_results = list(client.results(filtered_search))
print(f"Found {len(filtered_results)} filtered results")
for i, result in enumerate(filtered_results, 1):
    print(f"{i}. {result.title}")
    print(f"   Published: {result.published_date}")
# Out:
# 2025-06-03 15:50:07,388 - chemrxiv.client - INFO - Making search request: https://chemrxiv.org/engage/chemrxiv/public-api/v1/items?term=catalysis&limit=3&sort=PUBLISHED_DATE_DESC&searchDateFrom=2023-01-01T00%3A00%3A00.000Z&searchDateTo=2025-05-19T00%3A00%3A00.000Z&categoryIds=605c72ef153207001f6470d4
# 2025-06-03 15:50:07,388 - chemrxiv.client - INFO - Requesting URL (retry 0): https://chemrxiv.org/engage/chemrxiv/public-api/v1/items?term=catalysis&limit=3&sort=PUBLISHED_DATE_DESC&searchDateFrom=2023-01-01T00%3A00%3A00.000Z&searchDateTo=2025-05-19T00%3A00%3A00.000Z&categoryIds=605c72ef153207001f6470d4
# 2025-06-03 15:50:07,503 - urllib3.connectionpool - DEBUG - https://chemrxiv.org:443 "GET /engage/chemrxiv/public-api/v1/items?term=catalysis&limit=3&sort=PUBLISHED_DATE_DESC&searchDateFrom=2023-01-01T00%3A00%3A00.000Z&searchDateTo=2025-05-19T00%3A00%3A00.000Z&categoryIds=605c72ef153207001f6470d4 HTTP/1.1" 200 None
# 2025-06-03 15:50:07,504 - chemrxiv.client - INFO - API returned total count: 2496
# 2025-06-03 15:50:07,505 - chemrxiv.client - INFO - Found 3 items in response
# 2025-06-03 15:50:07,505 - chemrxiv.client - INFO - Processed item: 6824105250018ac7c50e40d8 - N-N Bond Formation Through N-H Dehydrocoupling
# 2025-06-03 15:50:07,505 - chemrxiv.client - INFO - Processed item: 6823b289927d1c2e669d3033 - From Plastic Waste to Pharmaceutical
# Precursors: PET Upcycling through
# Ruthenium Catalysed Semi-Hydrogenation
# 2025-06-03 15:50:07,505 - chemrxiv.client - INFO - Processed item: 681c0414e561f77ed486e335 - Catalytic 1,2-Radical Acyloxy Migration (RAM): A Strategy to Access Novel Chemical Space and Reaction Profiles
# Found 3 filtered results
# 1. N-N Bond Formation Through N-H Dehydrocoupling
#    Published: 2025-05-16 20:46:11.675000+00:00
# 2. From Plastic Waste to Pharmaceutical
# Precursors: PET Upcycling through
# Ruthenium Catalysed Semi-Hydrogenation
#    Published: 2025-05-16 19:52:23.844000+00:00
# 3. Catalytic 1,2-Radical Acyloxy Migration (RAM): A Strategy to Access Novel Chemical Space and Reaction Profiles
#    Published: 2025-05-16 18:09:51.435000+00:00
